# %%
import pandas as pd

# %%
df_oecd = pd.read_csv('/Users/MitaShunosuke/Library/CloudStorage/OneDrive-TheUniversityofTokyo/ダウンロード/修士課程/M1A/情報可視化の理論と実践/infovis-notebooks/final_report/OECD.ELS.SAE,DSD_TENURE@DF_TENURE_AVE,1.0+.TENURE_EMP..._T..A.csv')
df_oecd = df_oecd[(df_oecd['Job tenure'] == "Total") & (df_oecd['TIME_PERIOD'] == 2015)]

# %%
df_oecd.head()
# Out:
#     STRUCTURE                                STRUCTURE_ID  \
# 190  DATAFLOW  OECD.ELS.SAE:DSD_TENURE@DF_TENURE_AVE(1.0)
# 231  DATAFLOW  OECD.ELS.SAE:DSD_TENURE@DF_TENURE_AVE(1.0)
# 271  DATAFLOW  OECD.ELS.SAE:DSD_TENURE@DF_TENURE_AVE(1.0)
# 281  DATAFLOW  OECD.ELS.SAE:DSD_TENURE@DF_TENURE_AVE(1.0)
# 326  DATAFLOW  OECD.ELS.SAE:DSD_TENURE@DF_TENURE_AVE(1.0)
#
#                                         STRUCTURE_NAME ACTION REF_AREA  \
# 190  Employment by job tenure intervals - average j...      I      AUT
# 231  Employment by job tenure intervals - average j...      I      POL
# 271  Employment by job tenure intervals - average j...      I      POL
# 281  Employment by job tenure intervals - average j...      I      SVN
# 326  Employment by job tenure intervals - average j...      I      LTU
#
#     Reference area     MEASURE            Measure UNIT_MEASURE  \
# 190        Austria  TENURE_EMP  Employment tenure            Y
# ...
